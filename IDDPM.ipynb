# %% [markdown]
# <a href="https://colab.research.google.com/github/ali-alhwayzee/0xDeCA10B/blob/main/IDDPM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *clone from github*

# %%
# !git clone https://github.com/openai/improved-diffusion.git
# %cd improved-diffusion
# Out:
# Cloning into 'improved-diffusion'...
# remote: Enumerating objects: 58, done.
# remote: Counting objects: 100% (23/23), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 58 (delta 10), reused 9 (delta 8), pack-reused 35
# Receiving objects: 100% (58/58), 50.03 KiB | 12.51 MiB/s, done.
# Resolving deltas: 100% (17/17), done.
# /content/improved-diffusion

# %% [markdown]
# **install requierments**

# %%
# !pip install -e .
# Out:
# Obtaining file:///content/improved-diffusion
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.7/73.7 kB 1.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 23.5 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...

# %% [markdown]
# # **prepare dataset**

# %%
# !python /content/improved-diffusion/datasets/cifar10.py
# Out:
# downloading...
# ...
# 100% 170498071/170498071 [00:13<00:00, 12729282.03it/s]
# Extracting /tmp/tmpttoz0rkg/cifar-10-python.tar.gz to /tmp/tmpttoz0rkg
# dumping images...
# 100% 50000/50000 [00:19<00:00, 2503.52it/s]
# downloading...
# ...
# 100% 170498071/170498071 [00:13<00:00, 12364660.58it/s]
# Extracting /tmp/tmpnhtnom65/cifar-10-python.tar.gz to /tmp/tmpnhtnom65
# dumping images...
# 100% 10000/10000 [00:03<00:00, 2787.23it/s]

# %% [markdown]
# *install* **mpi**

# %%
# !pip install mpi4py
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 41.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for mpi4py: filename=mpi4py-3.1.6-cp310-cp310-linux_x86_64.whl size=2746306 sha256=e9ae7c2b312d1700ccb23b2dc00c5ce0f2864f08b1db9c4033126b499a2a7215
#   Stored in directory: /root/.cache/pip/wheels/4c/ca/89/8fc1fb1c620afca13bb41c630b1f948bbf446e0aaa4b762e10
# Successfully built mpi4py
# ...

# %% [markdown]
# **training**

# %%
# !python /content/improved-diffusion/scripts/image_train.py --data_dir /content/improved-diffusion/cifar_train $MODEL_FLAGS $DIFFUSION_FLAGS $TRAIN_FLAGS
# Out:
# Streaming output truncated to the last 5000 lines.
# | loss_q3   | 0.00143  |
# | mse       | 0.0306   |
# | mse_q0    | 0.0691   |
# | mse_q1    | 0.0104   |
# | mse_q2    | 0.0044   |
# | mse_q3    | 0.00143  |
# | samples   | 6.73e+03 |
# | step      | 6.73e+03 |
# ------------------------
# ------------------------
# | grad_norm | 0.232    |
# | loss      | 0.0181   |
# | loss_q0   | 0.0351   |
# | loss_q1   | 0.0151   |
# | loss_q2   | 0.00425  |
# | loss_q3   | 0.00117  |
# | mse       | 0.0181   |
# | mse_q0    | 0.0351   |
# | mse_q1    | 0.0151   |
# | mse_q2    | 0.00425  |
# | mse_q3    | 0.00117  |
# | samples   | 6.74e+03 |
# | step      | 6.74e+03 |
# ------------------------
# ------------------------
# | grad_norm | 0.227    |
# | loss      | 0.0102   |
# | loss_q0   | 0.0365   |
# | loss_q1   | 0.0116   |
# | loss_q2   | 0.00423  |
# | loss_q3   | 0.00171  |
# | mse       | 0.0102   |
# | mse_q0    | 0.0365   |
# | mse_q1    | 0.0116   |
# | mse_q2    | 0.00423  |
# ...

# %%
# !bash /content/improved-diffusion/scripts/MODEL_FLAGS.sh
# !bash /content/improved-diffusion/scripts/DIFFUSION_FLAGS.sh

# %%
# !python /content/improved-diffusion/scripts/image_sample.py --model_path /content/improved-diffusion/scripts/mod/64x64_diffusion.pt
# Out:
# Logging to /tmp/openai-2024-05-21-16-15-57-477868
# creating model and diffusion...
# Traceback (most recent call last):
#   File "/content/improved-diffusion/scripts/image_sample.py", line 106, in <module>
#     main()
#   File "/content/improved-diffusion/scripts/image_sample.py", line 34, in main
#     dist_util.load_state_dict(args.model_path, map_location="cpu")
#   File "/content/improved-diffusion/improved_diffusion/dist_util.py", line 63, in load_state_dict
#     return th.load(io.BytesIO(data), **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/torch/serialization.py", line 1005, in load
#     with _open_zipfile_reader(opened_file) as opened_zipfile:
#   File "/usr/local/lib/python3.10/dist-packages/torch/serialization.py", line 457, in __init__
#     super().__init__(torch._C.PyTorchFileReader(name_or_buffer))
# RuntimeError: PytorchStreamReader failed reading zip archive: failed finding central directory
